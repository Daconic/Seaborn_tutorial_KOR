# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from glob import glob 
import seaborn as sns

# %%
file_name = glob("data/*.csv")[0]

# %%
df = pd.read_csv(file_name)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x123    11 non-null     float64
#  1   y1      11 non-null     float64
#  2   y2      11 non-null     float64
#  3   y3      11 non-null     float64
#  4   x4      11 non-null     float64
#  5   y4      11 non-null     float64
# dtypes: float64(6)
# memory usage: 656.0 bytes

# %%
df.describe()
# Out:
#             x123         y1         y2         y3         x4         y4
# count  11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean    9.000000   7.500909   7.500909   7.500000   9.000000   7.500909
# std     3.316625   2.031568   2.031657   2.030424   3.316625   2.030579
# min     4.000000   4.260000   3.100000   5.390000   8.000000   5.250000
# 25%     6.500000   6.315000   6.695000   6.250000   8.000000   6.170000
# 50%     9.000000   7.580000   8.140000   7.110000   8.000000   7.040000
# 75%    11.500000   8.570000   8.950000   7.980000   8.000000   8.190000
# max    14.000000  10.840000   9.260000  12.740000  19.000000  12.500000

# %%
df.head()
# Out:
#    x123    y1    y2     y3   x4    y4
# 0  10.0  8.04  9.14   7.46  8.0  6.58
# 1   8.0  6.95  8.14   6.77  8.0  5.76
# 2  13.0  7.58  8.74  12.74  8.0  7.71
# 3   9.0  8.81  8.77   7.11  8.0  8.84
# 4  11.0  8.33  9.26   7.81  8.0  8.47

# %%
df["x1"] = df["x123"] 
df["x2"] = df["x123"] 
df["x3"] = df["x123"]

# %%
df = df[["x1","y1","x2","y2","x3","y3","x4","y4"]]

# %%
data1 = df[["x1","y1"]].copy()

# %%
data1["dataset"] = 1

# %%
data1
# Out:
#       x1     y1  dataset
# 0   10.0   8.04        1
# 1    8.0   6.95        1
# 2   13.0   7.58        1
# 3    9.0   8.81        1
# 4   11.0   8.33        1
# 5   14.0   9.96        1
# 6    6.0   7.24        1
# 7    4.0   4.26        1
# 8   12.0  10.84        1
# 9    7.0   4.82        1
# 10   5.0   5.68        1

# %%
data2 = df.iloc[:,2:4].copy()

# %%
data2["dataset"] = 2

# %%
data2
# Out:
#       x2    y2  dataset
# 0   10.0  9.14        2
# 1    8.0  8.14        2
# 2   13.0  8.74        2
# 3    9.0  8.77        2
# 4   11.0  9.26        2
# 5   14.0  8.10        2
# 6    6.0  6.13        2
# 7    4.0  3.10        2
# 8   12.0  9.13        2
# 9    7.0  7.26        2
# 10   5.0  4.74        2

# %%
data3 = df.iloc[:,4:6].copy()

# %%
data3["dataset"] = 3

# %%
data4 = df.iloc[:,6:8].copy()
data4["dataset"] = 4

# %%
data4
# Out:
#       x4     y4  dataset
# 0    8.0   6.58        4
# 1    8.0   5.76        4
# 2    8.0   7.71        4
# 3    8.0   8.84        4
# 4    8.0   8.47        4
# 5    8.0   7.04        4
# 6    8.0   5.25        4
# 7   19.0  12.50        4
# 8    8.0   5.56        4
# 9    8.0   7.91        4
# 10   8.0   6.89        4

# %%
data1.columns = ["x","y","dataset"]
data2.columns = ["x","y","dataset"]
data3.columns = ["x","y","dataset"]
data4.columns = ["x","y","dataset"]

# %%
df_1 = pd.concat([data1,data2,data3,data4], ignore_index=True)

# %%
df_1
# Out:
#        x      y  dataset
# 0   10.0   8.04        1
# 1    8.0   6.95        1
# 2   13.0   7.58        1
# 3    9.0   8.81        1
# 4   11.0   8.33        1
# 5   14.0   9.96        1
# 6    6.0   7.24        1
# 7    4.0   4.26        1
# 8   12.0  10.84        1
# 9    7.0   4.82        1
# 10   5.0   5.68        1
# 11  10.0   9.14        2
# 12   8.0   8.14        2
# 13  13.0   8.74        2
# 14   9.0   8.77        2
# 15  11.0   9.26        2
# 16  14.0   8.10        2
# 17   6.0   6.13        2
# 18   4.0   3.10        2
# 19  12.0   9.13        2
# 20   7.0   7.26        2
# 21   5.0   4.74        2
# 22  10.0   7.46        3
# 23   8.0   6.77        3
# 24  13.0  12.74        3
# 25   9.0   7.11        3
# 26  11.0   7.81        3
# 27  14.0   8.84        3
# 28   6.0   6.08        3
# 29   4.0   5.39        3
# 30  12.0   8.15        3
# 31   7.0   6.42        3
# 32   5.0   5.73        3
# 33   8.0   6.58        4
# 34   8.0   5.76        4
# 35   8.0   7.71        4
# ...

# %%
sns.lmplot(data=df_1, x="x", y="y", col="dataset", hue="dataset",
          col_wrap=2, palette="flare", ci=None,
          height=4, scatter_kws={"s":50,"alpha":1}
          )
